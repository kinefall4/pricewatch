# %% [markdown]
# # Test A — validation catches bad input (example)

# %%
import pandas as pd

bad = pd.DataFrame([
    {"date":"2026-01-01","item":"rice","price":-5}
])
bad
# Out:
#          date  item  price
# 0  2026-01-01  rice     -5

# %% [markdown]
# ## Your pipeline should fail if price ≤ 0 (showing your validation rule).

# %% [markdown]
# # Test B — automation proof
#
# ##  Pushed a commit to GitHub, it triggered CodeBuild via webhook, and the site redeployed to S3.
# ![codebuild_success.png](attachment:4b6f1674-b394-4e3d-8c84-3a8ee1650b8a.png)

# %% [markdown]
# ## Live Website
# ![livesite.png](attachment:5043a47c-6d62-4630-9519-0bd6d8ed05cb.png)
